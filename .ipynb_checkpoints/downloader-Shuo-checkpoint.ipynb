# %%
# -*- coding: utf-8 -*-
"""
A downloader that catch the data from Chinese land data website.

Yuhao Zhu

20170224: Creation of the file and adjust the code.
20170225: Create a log file for links that are not able to connect.
"""

import requests, re, os, sys, csv, datetime
from bs4 import BeautifulSoup

# %%
class Downloader():
    def __init__(self):
        self.url='http://www.landchina.com/default.aspx?tabid=263'
        # 2011年后的出让公告
        self.post_data={'TAB_QueryConditionItem':'9f2c3acd-0256-4da2-a659-6949c4671a2a',
                        'TAB_QuerySortItemList':'282:False',
                        # date
                        'TAB_QuerySubmitConditionData':'9f2c3acd-0256-4da2-a659-6949c4671a2a:',  
                        'TAB_QuerySubmitOrderData':'282:False',
                        # page number
                        'TAB_QuerySubmitPagerData':''} 
        self.row_name=[u'行政区', u'电子监管号', u'项目名称', u'项目位置', u'面积(公顷)', u'土地来源',
                      u'土地用途', u'供地方式', u'土地使用年限', u'行业分类', u'土地级别', u'成交价格(万元)',
                      u'土地使用权人', u'约定容积率下限', u'约定容积率上限', u'约定交地时间', u'约定开工时间',
                      u'约定竣工时间', u'实际开工时间', u'实际竣工时间', u'批准单位', u'合同签订日期']
        # 要抓取的数据名称。除了"分期约定"的四项以外全部抓取
        self.information=[
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r1_c2_ctrl',#0
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r1_c4_ctrl',#1
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r17_c2_ctrl',#2
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r16_c2_ctrl',#3
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r2_c2_ctrl',#4
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r2_c4_ctrl',#5
            # 此条为土地来源，抓取为数字，经过换算方得土地来源。
            # 如果‘土地来源’=0 则为’新增建设用地‘
            # 如果’土地来源=‘土地用途’ 则为‘现有建设用地’
            # 如果其他 则为‘新增建设用地（来自存量库）’。
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r3_c2_ctrl',#6  
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r3_c4_ctrl',#7
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r19_c2_ctrl', #8              
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r19_c4_ctrl',#9
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r20_c2_ctrl',#10
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r20_c4_ctrl',#11
##          'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f3_r2_c1_0_ctrl',
##          'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f3_r2_c2_0_ctrl',
##          'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f3_r2_c3_0_ctrl',
##          'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f3_r2_c4_0_ctrl',
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r9_c2_ctrl',#12
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f2_r1_c2_ctrl',
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f2_r1_c4_ctrl',
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r21_c4_ctrl',
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r22_c2',
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r22_c4_ctrl',
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r10_c2_ctrl',
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r10_c4_ctrl',                
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r14_c2_ctrl',
            'mainModuleContainer_1855_1856_ctl00_ctl00_p1_f1_r14_c4_ctrl']

# Step 1
    def date_format(self,year,month,day):
        """
        Import year, month and day, and return date format %Y-%m-%d
        """
        date = datetime.date(year, month, day)
        return date
    
    def days_in_month(self,year,month):
        """
        Calculate how many days in a specific month.
        """
        date = datetime.date(year, month, 1) # The date of the first day of a certain month.
        try:    
            date_next = datetime.date(date.year, date.month + 1, date.day) # The date of the first day of next month.
        except:
            date_next = datetime.date(date.year + 1, 1, date.day)  
        date_distance = (date_next - date).days # How many days in between.
        return date_distance
    
    def get_page_content(self, page_number, date):
        """
        Specify the date to be searched, open the first corresponding page, get the contents.
        """
        post_data = self.post_data.copy()
        # set up the dates to be searched.
        query_date = date.strftime('%Y-%m-%d') + '~' + date.strftime('%Y-%m-%d')
        post_data['TAB_QuerySubmitConditionData'] += query_date
        # set up the page
        post_data['TAB_QuerySubmitPagerData'] = str(page_number)
        try:
        # request the url
            r = requests.post(self.url, data=post_data, timeout=60)
            r.encoding='gb18030'
            page_content = r.text
        except:
            print('Loading page {} timeout!'.format(self.url))
            page_content = u'没有检索到相关数据'
        return page_content

# Step 2
    def get_all_number(self, date):
        """
        Find the number of pages for the date being searched.
        Case 1: no content
        Case 2: only one page of result
        Case 3: 1 to 200 pages
        Case 4: 200 pages above.
        """  
        first_content = self.get_page_content(1, date)
        if u'没有检索到相关数据' in first_content:
            print('Date {} have 0 page.'.format(date))
            return 0
        pattern = re.compile(u'<td.*?class="pager".*?>共(.*?)页.*?</td>')
        result = re.search(pattern, first_content)
        if result == None:
            print('Date {} have 1 page.'.format(date))
            return 1
        if int(result.group(1)) <= 200:
            print('Date {0} have {1} pages.'.format(date, int(result.group(1))))
            return int(result.group(1))
        else:
            print('Date {} have more than 200 pages. Only first 200 pages will be downloaded!'.format(date))
            return 200
        
# Step 3
    def get_links(self, page_number, date):
        """get links from a page"""
        page_content = self.get_page_content(page_number, date)
        links = []
        pattern = re.compile(u'<a.*?href="default.aspx.*?tabid=386(.*?)".*?>', re.S)
        results = re.findall(pattern, page_content)
        for result in results:
            links.append('http://www.landchina.com/default.aspx?tabid=386' + result)
        return links
    
    def get_all_links(self, all_number, date):
        """get all links"""
        page_number = 1
        all_links = []
        while page_number <= all_number:
            links = self.get_links(page_number, date)
            all_links += links
            print('Get links from the page {0} out of {1}.'.format(page_number, all_number))
            page_number += 1
        print('Date {0} have {1} links.'.format(date, len(all_links)))
        return all_links
    
# Step 4
    def get_link_content(self, link):
        """
        Open the link to get the content of that link. The content is the report.
        """
        try:
            r=requests.get(link, timeout=60)
            r.encoding='gb18030'
            link_content = r.text
        except:
            print('Loading report from {} timeout!'.format(link))
            link_content = ""
            error_file_name = 'landchina/error.csv'
            if os.path.exists(error_file_name):
                mode = 'a'
            else:
                mode = 'w'
            csv_file = open(error_file_name, mode, encoding='utf-8-sig')
            writer = csv.writer(csv_file)
            writer.writerow(['{}'.format(link)])
            csv_file.close()
        return link_content
    
    def get_information(self,link_content):
        """
        Get information from every item.
        """
        data = []
        soup = BeautifulSoup(link_content, 'lxml')
        for item in self.information:
            if soup.find(id=item) == None:
                s = ''
            else:
                s = soup.find(id=item).string
                if s == None:
                    s=''                
            data.append(s.strip())
        return data
    
    def save_information(self, data, date):
        """
        Save the information to the file.
        """
#         path is "landchina/year/month/day.csv"
        file_name = 'landchina/{0}/{1}/{2}.csv'.format(datetime.datetime.strftime(date,'%Y'),
                                                      datetime.datetime.strftime(date,'%m'),
                                                      datetime.datetime.strftime(date,'%d'))
        if os.path.exists(file_name):
            mode = 'a'
        else:
            mode = 'w'
        csv_file = open(file_name, mode, encoding='utf-8-sig')
        writer = csv.writer(csv_file)
        if mode == 'w':
            writer.writerow([name for name in self.row_name])
        writer.writerow([d for d in data])
        csv_file.close()
        
    def make_directory(self, date):
        """
        Create the directory.
        """
        path = 'landchina/{0}/{1}'.format(datetime.datetime.strftime(date,'%Y'),
                                          datetime.datetime.strftime(date,'%m'))
        isExists = os.path.exists(path)
        if not isExists:
            os.makedirs(path)
            
    def save_all_information(self, all_links, date):
        """
        Save all information from the website.
        """
        for (i,link) in enumerate(all_links):
            link_content = data = None
            link_content = self.get_link_content(link)
            data = self.get_information(link_content)
            self.make_directory(date)
            self.save_information(data, date)
            print('Save information from link {0} out of {1}.'.format(i+1, len(all_links)))

# %%
machine = Downloader()

# Date
year = 2016
month = 9
day = 1
days = machine.days_in_month(year, month)

print('Start downloading!\n')
# Download month by month
while day <= days:
    # date
    date = machine.date_format(year, month, day)
    # page
    all_number = machine.get_all_number(date)
    # link
    all_links = machine.get_all_links(all_number, date)
    # information
    machine.save_all_information(all_links, date)
    day += 1
    print('The information for date {} is all downloaded!\n'.format(date))
print('The information for month {} is all downloaded!'.format(date.strftime('%Y-%m')))
# Out:
# Start downloading!
#
# Date 2016-10-01 have more than 200 pages. Only first 200 pages will be downloaded!
# Get links from the page 1 out of 200.
# Get links from the page 2 out of 200.
# Get links from the page 3 out of 200.
# Get links from the page 4 out of 200.
# Get links from the page 5 out of 200.
# Get links from the page 6 out of 200.
# Get links from the page 7 out of 200.
# Get links from the page 8 out of 200.
# Get links from the page 9 out of 200.
# Get links from the page 10 out of 200.
# Get links from the page 11 out of 200.
# Get links from the page 12 out of 200.
# Get links from the page 13 out of 200.
# Get links from the page 14 out of 200.
# Get links from the page 15 out of 200.
# Get links from the page 16 out of 200.
# Get links from the page 17 out of 200.
# Get links from the page 18 out of 200.
# Get links from the page 19 out of 200.
# Get links from the page 20 out of 200.
# Get links from the page 21 out of 200.
# Get links from the page 22 out of 200.
# Get links from the page 23 out of 200.
# Get links from the page 24 out of 200.
# Get links from the page 25 out of 200.
# Get links from the page 26 out of 200.
# Get links from the page 27 out of 200.
# Get links from the page 28 out of 200.
# Get links from the page 29 out of 200.
# Get links from the page 30 out of 200.
# Get links from the page 31 out of 200.
# Get links from the page 32 out of 200.
# Get links from the page 33 out of 200.
# Get links from the page 34 out of 200.
# Get links from the page 35 out of 200.
# Get links from the page 36 out of 200.
# Get links from the page 37 out of 200.
# Get links from the page 38 out of 200.
# Get links from the page 39 out of 200.
# Get links from the page 40 out of 200.
# Get links from the page 41 out of 200.
# Get links from the page 42 out of 200.
# Get links from the page 43 out of 200.
# Get links from the page 44 out of 200.
# Get links from the page 45 out of 200.
# Get links from the page 46 out of 200.
# Get links from the page 47 out of 200.
# Get links from the page 48 out of 200.
# Get links from the page 49 out of 200.
# Get links from the page 50 out of 200.
# Get links from the page 51 out of 200.
# Get links from the page 52 out of 200.
# Get links from the page 53 out of 200.
# Get links from the page 54 out of 200.
# Get links from the page 55 out of 200.
# Get links from the page 56 out of 200.
# Get links from the page 57 out of 200.
# Get links from the page 58 out of 200.
# Get links from the page 59 out of 200.
# Get links from the page 60 out of 200.
# Get links from the page 61 out of 200.
# Get links from the page 62 out of 200.
# Get links from the page 63 out of 200.
# Get links from the page 64 out of 200.
# Get links from the page 65 out of 200.
# Get links from the page 66 out of 200.
# Get links from the page 67 out of 200.
# Get links from the page 68 out of 200.
# Get links from the page 69 out of 200.
# Get links from the page 70 out of 200.
# Get links from the page 71 out of 200.
# Get links from the page 72 out of 200.
# Get links from the page 73 out of 200.
# Get links from the page 74 out of 200.
# Get links from the page 75 out of 200.
# Get links from the page 76 out of 200.
# Get links from the page 77 out of 200.
# Get links from the page 78 out of 200.
# Get links from the page 79 out of 200.
# Get links from the page 80 out of 200.
# Get links from the page 81 out of 200.
# Get links from the page 82 out of 200.
# Get links from the page 83 out of 200.
# Get links from the page 84 out of 200.
# Get links from the page 85 out of 200.
# Get links from the page 86 out of 200.
# Get links from the page 87 out of 200.
# Get links from the page 88 out of 200.
# Get links from the page 89 out of 200.
# Get links from the page 90 out of 200.
# Get links from the page 91 out of 200.
# Get links from the page 92 out of 200.
# Get links from the page 93 out of 200.
# Get links from the page 94 out of 200.
# Get links from the page 95 out of 200.
# Get links from the page 96 out of 200.
# Get links from the page 97 out of 200.
# Get links from the page 98 out of 200.
# Get links from the page 99 out of 200.
# Get links from the page 100 out of 200.
# Get links from the page 101 out of 200.
# Get links from the page 102 out of 200.
# Get links from the page 103 out of 200.
# Get links from the page 104 out of 200.
# Get links from the page 105 out of 200.
# Get links from the page 106 out of 200.
# Get links from the page 107 out of 200.
# Get links from the page 108 out of 200.
# Get links from the page 109 out of 200.
# Get links from the page 110 out of 200.
# Get links from the page 111 out of 200.
# Get links from the page 112 out of 200.
# Get links from the page 113 out of 200.
# Get links from the page 114 out of 200.
# Get links from the page 115 out of 200.
# Get links from the page 116 out of 200.
# Get links from the page 117 out of 200.
# Get links from the page 118 out of 200.
# Get links from the page 119 out of 200.
# Get links from the page 120 out of 200.
# Get links from the page 121 out of 200.
# Get links from the page 122 out of 200.
# Get links from the page 123 out of 200.
# Get links from the page 124 out of 200.
# Get links from the page 125 out of 200.
# Get links from the page 126 out of 200.
# Get links from the page 127 out of 200.
# Get links from the page 128 out of 200.
# Get links from the page 129 out of 200.
# Get links from the page 130 out of 200.
# Get links from the page 131 out of 200.
# Get links from the page 132 out of 200.
# Get links from the page 133 out of 200.
# Get links from the page 134 out of 200.
# Get links from the page 135 out of 200.
# Get links from the page 136 out of 200.
# Get links from the page 137 out of 200.
# Get links from the page 138 out of 200.
# Get links from the page 139 out of 200.
# Get links from the page 140 out of 200.
# Get links from the page 141 out of 200.
# Get links from the page 142 out of 200.
# Get links from the page 143 out of 200.
# Get links from the page 144 out of 200.
# Get links from the page 145 out of 200.
# Get links from the page 146 out of 200.
# Get links from the page 147 out of 200.
# Get links from the page 148 out of 200.
# Get links from the page 149 out of 200.
# Get links from the page 150 out of 200.
# Get links from the page 151 out of 200.
# Get links from the page 152 out of 200.
# Get links from the page 153 out of 200.
# Get links from the page 154 out of 200.
# Get links from the page 155 out of 200.
# Get links from the page 156 out of 200.
# Get links from the page 157 out of 200.
# Get links from the page 158 out of 200.
# Get links from the page 159 out of 200.
# Get links from the page 160 out of 200.
# Get links from the page 161 out of 200.
# Get links from the page 162 out of 200.
# Get links from the page 163 out of 200.
# Get links from the page 164 out of 200.
# Get links from the page 165 out of 200.
# Get links from the page 166 out of 200.
# Get links from the page 167 out of 200.
# Get links from the page 168 out of 200.
# Get links from the page 169 out of 200.
# Get links from the page 170 out of 200.
# Get links from the page 171 out of 200.
# Get links from the page 172 out of 200.
# Get links from the page 173 out of 200.
# Get links from the page 174 out of 200.
# Get links from the page 175 out of 200.
# Get links from the page 176 out of 200.
# Get links from the page 177 out of 200.
# Get links from the page 178 out of 200.
# Get links from the page 179 out of 200.
# Get links from the page 180 out of 200.
# Get links from the page 181 out of 200.
# Get links from the page 182 out of 200.
# Get links from the page 183 out of 200.
# Get links from the page 184 out of 200.
# Get links from the page 185 out of 200.
# Get links from the page 186 out of 200.
# Get links from the page 187 out of 200.
# Get links from the page 188 out of 200.
# Get links from the page 189 out of 200.
# Get links from the page 190 out of 200.
# Get links from the page 191 out of 200.
# Get links from the page 192 out of 200.
# Get links from the page 193 out of 200.
# Get links from the page 194 out of 200.
# Get links from the page 195 out of 200.
# Get links from the page 196 out of 200.
# Get links from the page 197 out of 200.
# Get links from the page 198 out of 200.
# Get links from the page 199 out of 200.
# Get links from the page 200 out of 200.
# Date 2016-10-01 have 15 links.
# Save information from link 1 out of 15.
# Save information from link 2 out of 15.
# Save information from link 3 out of 15.
# Save information from link 4 out of 15.
# Save information from link 5 out of 15.
# Save information from link 6 out of 15.
# Save information from link 7 out of 15.
# Save information from link 8 out of 15.
# Save information from link 9 out of 15.
# Save information from link 10 out of 15.
# Save information from link 11 out of 15.
# Save information from link 12 out of 15.
# Save information from link 13 out of 15.
# Save information from link 14 out of 15.
# Save information from link 15 out of 15.
# The information for date 2016-10-01 is all downloaded!
#
# Date 2016-10-02 have 1 page.
# Get links from the page 1 out of 1.
# Date 2016-10-02 have 16 links.
# Save information from link 1 out of 16.
# Save information from link 2 out of 16.
# Save information from link 3 out of 16.
# Save information from link 4 out of 16.
# Save information from link 5 out of 16.
# Save information from link 6 out of 16.
# Save information from link 7 out of 16.
# Save information from link 8 out of 16.
# Save information from link 9 out of 16.
# Save information from link 10 out of 16.
# Save information from link 11 out of 16.
# Save information from link 12 out of 16.
# Save information from link 13 out of 16.
# Save information from link 14 out of 16.
# Save information from link 15 out of 16.
# Save information from link 16 out of 16.
# The information for date 2016-10-02 is all downloaded!
#
# Date 2016-10-03 have 1 page.
# Get links from the page 1 out of 1.
# Date 2016-10-03 have 12 links.
# Save information from link 1 out of 12.
# Save information from link 2 out of 12.
# Save information from link 3 out of 12.
# Save information from link 4 out of 12.
# Save information from link 5 out of 12.
# Save information from link 6 out of 12.
# Save information from link 7 out of 12.
# Save information from link 8 out of 12.
# Save information from link 9 out of 12.
# Save information from link 10 out of 12.
# Save information from link 11 out of 12.
# Save information from link 12 out of 12.
# The information for date 2016-10-03 is all downloaded!
#
# Date 2016-10-04 have 1 page.
# Get links from the page 1 out of 1.
# Date 2016-10-04 have 30 links.
# Save information from link 1 out of 30.
# Save information from link 2 out of 30.
# Save information from link 3 out of 30.
# Save information from link 4 out of 30.
# Save information from link 5 out of 30.
# Save information from link 6 out of 30.
# Save information from link 7 out of 30.
# Save information from link 8 out of 30.
# Save information from link 9 out of 30.
# Save information from link 10 out of 30.
# Save information from link 11 out of 30.
# Loading report from http://www.landchina.com/default.aspx?tabid=386&comname=default&wmguid=75c72564-ffd9-426a-954b-8ac2df0903b7&recorderguid=3D602285A0DF6705E055000000000001 timeout!
# Save information from link 12 out of 30.
# Save information from link 13 out of 30.
# Save information from link 14 out of 30.
# Save information from link 15 out of 30.
# Save information from link 16 out of 30.
# Save information from link 17 out of 30.
# Save information from link 18 out of 30.
# Save information from link 19 out of 30.
# Save information from link 20 out of 30.
# Save information from link 21 out of 30.
# Save information from link 22 out of 30.
# Save information from link 23 out of 30.
# Save information from link 24 out of 30.
# Save information from link 25 out of 30.
# Save information from link 26 out of 30.
# Save information from link 27 out of 30.
# Save information from link 28 out of 30.
# Save information from link 29 out of 30.
# Loading report from http://www.landchina.com/default.aspx?tabid=386&comname=default&wmguid=75c72564-ffd9-426a-954b-8ac2df0903b7&recorderguid=57758c28-d185-4fc7-9e33-44e8a00de11f timeout!
# Save information from link 30 out of 30.
# The information for date 2016-10-04 is all downloaded!
#
# Date 2016-10-05 have 1 page.
# Get links from the page 1 out of 1.
# Date 2016-10-05 have 26 links.
# Save information from link 1 out of 26.
# Save information from link 2 out of 26.
# Save information from link 3 out of 26.
# Save information from link 4 out of 26.
# Save information from link 5 out of 26.
# Save information from link 6 out of 26.
# Save information from link 7 out of 26.
# Save information from link 8 out of 26.
# Save information from link 9 out of 26.
# Save information from link 10 out of 26.
# Save information from link 11 out of 26.
# Save information from link 12 out of 26.
# Save information from link 13 out of 26.
# Save information from link 14 out of 26.
# Save information from link 15 out of 26.
# Save information from link 16 out of 26.
# Save information from link 17 out of 26.
# Save information from link 18 out of 26.
# Save information from link 19 out of 26.
# Loading report from http://www.landchina.com/default.aspx?tabid=386&comname=default&wmguid=75c72564-ffd9-426a-954b-8ac2df0903b7&recorderguid=87ffbd19-3a59-4e31-9198-b57571119ad1 timeout!
# Save information from link 20 out of 26.
# Save information from link 21 out of 26.
# Save information from link 22 out of 26.
# Save information from link 23 out of 26.
# Save information from link 24 out of 26.
# Save information from link 25 out of 26.
# Save information from link 26 out of 26.
# The information for date 2016-10-05 is all downloaded!
#
# Date 2016-10-06 have 1 page.
# Get links from the page 1 out of 1.
# Date 2016-10-06 have 20 links.
# Save information from link 1 out of 20.
# Save information from link 2 out of 20.
# Save information from link 3 out of 20.
# Save information from link 4 out of 20.
# Save information from link 5 out of 20.
# Save information from link 6 out of 20.
# Save information from link 7 out of 20.
# Save information from link 8 out of 20.
# Loading report from http://www.landchina.com/default.aspx?tabid=386&comname=default&wmguid=75c72564-ffd9-426a-954b-8ac2df0903b7&recorderguid=cb7c62cb-0dc6-44f7-ab2f-d486598708c7 timeout!
# Save information from link 9 out of 20.
# Save information from link 10 out of 20.
# Save information from link 11 out of 20.
# Save information from link 12 out of 20.
# Save information from link 13 out of 20.
# Save information from link 14 out of 20.
# Save information from link 15 out of 20.
# Loading report from http://www.landchina.com/default.aspx?tabid=386&comname=default&wmguid=75c72564-ffd9-426a-954b-8ac2df0903b7&recorderguid=d314ee4c-d35b-40ae-ad55-57882807155f timeout!
# Save information from link 16 out of 20.
# Save information from link 17 out of 20.
# Save information from link 18 out of 20.
# Save information from link 19 out of 20.
# Save information from link 20 out of 20.
# The information for date 2016-10-06 is all downloaded!
#
# Date 2016-10-07 have 1 page.
# Loading page http://www.landchina.com/default.aspx?tabid=263 timeout!
# Get links from the page 1 out of 1.
# Date 2016-10-07 have 0 links.
# The information for date 2016-10-07 is all downloaded!
#
# Date 2016-10-08 have 19 pages.
# Get links from the page 1 out of 19.
# Get links from the page 2 out of 19.
# Get links from the page 3 out of 19.
# Get links from the page 4 out of 19.
# Get links from the page 5 out of 19.
# Get links from the page 6 out of 19.
# Get links from the page 7 out of 19.
